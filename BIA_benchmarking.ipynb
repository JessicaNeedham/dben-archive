# %% [markdown]
# ## BIA ensemble processing

# %% [markdown]
# #### Libraries

# %%
from scipy.stats import qmc
import numpy as np
import xarray as xr
import csv
import pandas as pd
import os
import netCDF4 as nc4
import sys
from tempfile import TemporaryFile                                                                                                                                 
import argparse                                                                                                                                                     
import shutil                                                                                                                                                       
import tempfile 
import random
from matplotlib.colors import BoundaryNorm

import functions_py.fates_xarray_functions as fa

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import cm
import matplotlib.colors as mcolors
from matplotlib.colors import Normalize

dark = cm.get_cmap('Paired', 12)
colormap = dark(range(12))
colormap[10] = colormap[11]
# Out:
# /global/homes/j/jneedham/.conda/envs/myenv/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# fig1, ((f1ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(6,3))
# f1ax0.scatter(np.arange(0,12,1), np.arange(0,12,1), color=colormap)

# %% [markdown]
# ## Load benchmarking data

# %% [markdown]
# ### Regrowth curves

# %%
# regrowth curves 
dfre = pd.read_csv('/global/homes/j/jneedham/DBEN/benchmarking_data/benchmark_regrowth_curves.csv')
dfre = dfre[dfre.Biome == 'Temperate']
#dfre.head(20)

# Bin_num here refers to time - these data are for plotting regrowth curves
# Columns are median, 10th and 90th percentiles

# %% [markdown]
# ### Stand structure - nplant and AGB by size

# %%
# stand structure data 
dfss = pd.read_csv('/global/homes/j/jneedham/DBEN/benchmarking_data/benchmark_stand_structure.csv')
dfss = dfss[dfss.site == 'BIA']
#dfss.head(5)

# %% [markdown]
# ### Equilibrium dynamics

# %%
# equilibrium dynamics
dfeq = pd.read_csv('/global/homes/j/jneedham/DBEN/benchmarking_data/benchmark_eq_dynamics.csv')
dfeq = dfeq[dfeq.site == 'BIA']
#dfeq.head(5)

# %%
# this function takes data that has monthly values and returns a single annual value, with 
# a mean that accounts for the number of days per month
def monthly_to_annual(array):
    """ calculate annual mean from monthly data, using unequal month lengths for noleap calendar.  
    originally written by Keith Lindsay."""
    mon_day  = xr.DataArray(np.array([31.,28.,31.,30.,31.,30.,31.,31.,30.,31.,30.,31.]), dims=['month'])
    mon_wgt  = mon_day/mon_day.sum()
    return (array.rolling(time=12, center=False) # rolling
            .construct("month") # construct the array
            .isel(time=slice(11, None, 12)) # slice so that the first element is [1..12], second is [13..24]
            .dot(mon_wgt, dims=["month"]))

# %% [markdown]
# ## FATES

# %%
fates1='/pscratch/sd/j/jneedham/elm_runs/dben/sims2024/bia_trendy_ensemble_1.E93ab10c892-F53b237c6.2024-05-23/run/bia_trendy_ensemble_1.E93ab10c892-F53b237c6.2024-05-23.h0.ensemble.sofar.nc'
fates1 = xr.open_dataset(fates1,  decode_times=False)

fates2='/pscratch/sd/j/jneedham/elm_runs/dben/sims2024/bia_trendy_ensemble_2.E93ab10c892-F53b237c6.2024-05-23/run/bia_trendy_ensemble_2.E93ab10c892-F53b237c6.2024-05-23.h0.ensemble.sofar.nc'
fates2 = xr.open_dataset(fates2,  decode_times=False)

fates = xr.concat([fates1, fates2], dim='record')

# %%
nyears = int(len(fates.variables['time'])/12)
time = fates.variables['time'] / 365.
print(nyears)

n_lat = len(fates.variables['lat'])
n_lon = len(fates.variables['lon'])

tave_start = (nyears-10)
tave_stop = nyears

print(tave_start)

cohort_size_bins = fates.variables['fates_levscls'][:]
nsizebins = len(cohort_size_bins)
patch_age_bins = fates.variables['fates_levage'][:]
ninst = n_lon
# Out:
# 280
# 270

# %% [markdown]
# ### Regrowth curves - full ensemble and time series

# %%
AGB = fates.FATES_VEGC_ABOVEGROUND
#AGB = np.squeeze(AGB.sum(dim='fates_levscpf'))

fig1, ((f1ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

for  i in range(0,ninst):
    if i == 0: 
        f1ax0.plot(time, AGB[i], color='green', label = 'FATES', alpha = 0.4)    
    else: 
        f1ax0.plot(time, AGB[i,:], color='green', alpha = 0.4)

f1ax0.set_title(r'AGB accumulation', fontsize = 12)
f1ax0.set_ylabel(r'AGB (kg C m$^{-2}$)', fontsize = 12)
f1ax0.set_xlabel(r'Time (years)', fontsize = 12)    
   
time_plot = dfre.bin_num
agb_plot = dfre.AGcwood_kgCm2_med

f1ax0.plot(time_plot, agb_plot, color='black', label = 'Plot Data')

f1ax0.legend(prop={'size':12})
;
# Out:
# ''

# %% [markdown]
# ### Equilibrium AGB

# %%
time_plot = list(dfeq.Year)
agb_plot = dfeq.AGB_kgCm2
agb_plot_lower = dfeq.AGB_lower_kgCm2
agb_plot_upper = dfeq.AGB_upper_kgCm2

eq_time = np.arange(time_plot[0], (time_plot[-1]+1), 1)
tstart = nyears-(len(eq_time))
tstop = nyears

AGB = monthly_to_annual(fates.FATES_VEGC_ABOVEGROUND)

fig1, ((f1ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

for  i in range(0,ninst):
    if i == 0: 
        f1ax0.plot(eq_time, AGB[i,tstart:tstop], color='green', label = 'FATES', alpha = 0.4)    
    else: 
        f1ax0.plot(eq_time, AGB[i,tstart:tstop], color='green', alpha = 0.4)

f1ax0.set_title(r' Equilibrium AGB', fontsize = 12)
f1ax0.set_ylabel(r'AGB (kg C m$^{-2}$)', fontsize = 12)
f1ax0.set_xlabel(r'Time (years)', fontsize = 12)    
   
f1ax0.plot(time_plot, agb_plot, color='black', label = 'Plot Data', linewidth=3)
f1ax0.fill_between(time_plot, agb_plot_lower, agb_plot_upper, alpha=0.6, facecolor='grey')

f1ax0.legend(prop={'size':12})
;
# Out:
# ''

# %%
# dbh_classes_num are UPPER  bounds. Remove the  first size  bin
plot_sizebin = np.array(dfss.dbh_classes_num)
plot_sizebin_mids = (plot_sizebin[0:-1] + plot_sizebin[1:])/2
plot_sizebin_widths = plot_sizebin[1:] - plot_sizebin[:-1]
plot_nplant = dfss['nstem_size_ha.1']

# size bins are LOWER bounds. Remove the fist bin - but add an extra bin to catch trees over last bin edge
cohort_size_bins_ex = np.append(cohort_size_bins[1:], 250)
fates_sizebin_mids = (cohort_size_bins_ex[0:-1] + cohort_size_bins_ex[1:])/2
fates_sizebin_widths = cohort_size_bins_ex[1:] - cohort_size_bins_ex[:-1]

# %%
nplant = monthly_to_annual(fates.FATES_NPLANT_SZ)
nplant = np.squeeze(nplant.isel(time=slice(tave_start,tave_stop)).mean(dim='time')) * 10000 # convert to plants per ha (from m-2)

plot_sd = plot_nplant.iloc[1:]/plot_sizebin_widths
fates_sd = nplant[:,1:]/fates_sizebin_widths


fig2, ((f2ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

for  i in range(0,ninst):
    if i == 0: 
        f2ax0.plot(fates_sizebin_mids, fates_sd[i,:], color='green', 
                   label = 'FATES', alpha = 0.4)    
    else: 
        f2ax0.plot(fates_sizebin_mids, fates_sd[i,:], color='green', alpha = 0.4)

f2ax0.set_title(r'Size distribution', fontsize = 12)
f2ax0.set_ylabel(r'Number of plants (ha$^{-1}$ cm$^{-2}$)', fontsize = 12)
f2ax0.set_xlabel(r'DBH (cm)', fontsize = 12)    
       
f2ax0.plot(plot_sizebin_mids, plot_sd, color='black', 
           label = 'Plot Data', linewidth = 3)
f2ax0.set_yscale('log')
#f2ax0.set_xscale('log')

f2ax0.legend(prop={'size':12})
;
# Out:
# ''

# %%
agb_frac = 0.6
WOODC = monthly_to_annual(fates.FATES_WOODC_SZ)
print(WOODC.shape)
WOODC = np.squeeze(WOODC.isel(time=slice(tave_start,tave_stop)).mean(dim='time')) * agb_frac

fates_agb_sd = WOODC[:,1:]/fates_sizebin_widths


fig3, ((f3ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

for  i in range(0,ninst):
    if i == 0: 
        f3ax0.plot(fates_sizebin_mids, fates_agb_sd[i,:], color='green', 
                   label = 'FATES', alpha = 0.4)    
    else: 
        f3ax0.plot(fates_sizebin_mids, fates_agb_sd[i,:], color='green', alpha = 0.4)

f3ax0.set_title(r'Aboveground woody carbon by size', fontsize = 12)
f3ax0.set_ylabel(r'Kg C (m$^{-2}$ cm$^{-2}$)', fontsize = 12)
f3ax0.set_xlabel(r'DBH (cm)', fontsize = 12)    
   
#dfss_bci.head(10)    
    
plot_cwood_sz = dfss['AGB_size_kgCm.2']
plot_agb_sd = plot_cwood_sz[1:]/plot_sizebin_widths
    
f3ax0.plot(plot_sizebin_mids, plot_agb_sd, color='black', label = 'Plot Data', 
          linewidth=3)

f3ax0.legend(prop={'size':12})
;
# Out:
# (256, 280, 16, 1)
# ''

# %% [markdown]
# ## Pick out the best ones

# %% [markdown]
# #### Equilibrium AGB fit

# %%
# Mean equilibrium plot AGB
agb_plot = dfeq.AGB_kgCm2
agb_plot_mu = np.mean(agb_plot)
print(agb_plot_mu)

# Mean equilibrium FATES AGB
AGB = monthly_to_annual(fates.FATES_VEGC_ABOVEGROUND)

agb_fates_mu = AGB.isel(time=slice(tave_start,tave_stop)).mean(dim='time')

# Find the ensemble members within 10% of equilibrium AGB
tmp = np.array(abs(agb_fates_mu - agb_plot_mu))
#print(tmp)

agb_eq_good = np.where(tmp < (agb_plot_mu * 0.05))[0]
print(agb_eq_good)
# Out:
# 11.788863227153799
# [44 70 82 90 92 93 96]

# %% [markdown]
# #### AGB regrowth fit

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
AGB = np.squeeze(monthly_to_annual(fates.FATES_VEGC_ABOVEGROUND))

time_plot = dfre.bin_num
print(time_plot)
agb_plot = dfre.AGcwood_kgCm2_med

AGB_regrowth_timepoints = AGB[:,time_plot[0:6]]

rmse_regrowth = []
for i in range(0,ninst): 
    rmse_regrowth.append(rmse(AGB_regrowth_timepoints[i,0:6], agb_plot[0:6]))
    
regrowth_best = rmse_regrowth.index(min(rmse_regrowth))
print(regrowth_best)
# Out:
# 4      10
# 5      30
# 6      50
# 7      70
# 8      90
# 9     110
# 10    130
# 11    150
# Name: bin_num, dtype: int64
# 211

# %% [markdown]
# #### Size distribution fit

# %%
rmse_sizedist = []
for i in range(0,ninst):
    rmse_sizedist.append(rmse(plot_sd, fates_sd[i,:]))
    
sizedist_best = rmse_sizedist.index(min(rmse_sizedist)) 
print(sizedist_best)
# Out:
# 0

# %% [markdown]
# #### AGB by size fit

# %%
rmse_agb_dist = []
for i in range(0,ninst):
    rmse_agb_dist.append(rmse(plot_agb_sd, fates_agb_sd[i,:]))
    
agb_dist_best = rmse_agb_dist.index(min(rmse_agb_dist)) 
print(agb_dist_best)
# Out:
# 90

# %% [markdown]
# #### Overall good runs?

# %%
good = np.concatenate((agb_eq_good, regrowth_best, sizedist_best, agb_dist_best), axis=None)
print(good)
# Out:
# [ 44  70  82  90  92  93  96 211   0  90]

# %% [markdown]
# ## AGB by PFT

# %%
AGB = monthly_to_annual(fates.FATES_VEGC_PF)

coex = []

for  i in range(0,len(good)):
    
    # percent total  biomass of each tree PFT
    AGBrec =  AGB.isel(record=good[i])
    AGBfinal = AGBrec.isel(time=nyears-1)
    total = AGBfinal.sum(dim=('fates_levpft'))
    pft1 = (AGBfinal.isel(fates_levpft=0)  / total ).values
    pft2 = (AGBfinal.isel(fates_levpft=1)  / total ).values
    pft3 = (AGBfinal.isel(fates_levpft=2)  / total ).values
     # make sure no PFT has more than 80% of biomass 
    if (pft1 < 0.8 and pft2 < 0.8  and pft3 < 0.8) :
        coex.append(good[i])
    
        
print(len(coex))
# Out:
# 8

# %%
AGB = fates.FATES_VEGC_PF

print(AGB.shape)
print(time.shape)

fig1, axs = plt.subplots(nrows=5,ncols=3, figsize=(16,12), constrained_layout=True, sharex=True, sharey=True)
axs=axs.flatten()

for  i in range(0,len(coex)):
    axs[i].plot(time, AGB[coex[i],:,0],label = 'ST NL')  
    axs[i].plot(time, AGB[coex[i],:,1], label = 'LD BL D')   
    axs[i].plot(time, AGB[coex[i],:,2],  label = 'ST BL D')   
    axs[i].plot(time, AGB[coex[i],:,3],  label = 'Grass')  
    axs[i].set_title(i)
    if i == 0:
        axs[i].legend(prop={'size':12})

fig1.supxlabel(r'Time (Years)', fontsize=16)
fig1.supylabel(r'AGB (kg C m-2)', fontsize=16)
# Out:
# (256, 3360, 4, 1)
# (3360,)
# Text(0.02, 0.5, 'AGB (kg C m-2)')

# %%
AGB = fates.FATES_VEGC_ABOVEGROUND

fig2, ((f2ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

for  i in range(0,len(coex)):
    f2ax0.plot(time, AGB[coex[i],], label = i, linewidth=2)  
   
f2ax0.set_title(r'AGB accumulation', fontsize = 12)
f2ax0.set_ylabel(r'AGB (kg C m$^{-2}$)', fontsize = 12)
f2ax0.set_xlabel(r'Time (years)', fontsize = 12)    
     
time_plot = dfre.bin_num
agb_plot = dfre.AGcwood_kgCm2_med
agb_plot_l = dfre.AGcwood_kgCm2_10
agb_plot_u = dfre.AGcwood_kgCm2_90

f2ax0.plot(time_plot, agb_plot, color='black', label = 'Plot Data', linewidth=3)
f2ax0.fill_between(time_plot, agb_plot_l, agb_plot_u, alpha=0.3, facecolor='grey')

f2ax0.legend(prop={'size':12})

# %%
fig2, ((f2ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

for  i in range(0,len(coex)):
        f2ax0.plot(fates_sizebin_mids, nplant[coex[i],1:]/fates_sizebin_widths, 
                   label = i, linewidth=2)    
   
f2ax0.set_title(r'Size distribution', fontsize = 12)
f2ax0.set_ylabel(r'Number of plants (ha$^{-1}$ cm$^{-2}$)', fontsize = 12)
f2ax0.set_xlabel(r'DBH (cm)', fontsize = 12)    
       
f2ax0.plot(plot_sizebin_mids, plot_nplant.iloc[1:]/plot_sizebin_widths, color='black',
           label = 'Plot Data', linewidth=3)
f2ax0.set_yscale('log')

f2ax0.legend(prop={'size':10})
;
# Out:
# ''

# %%
fig3, ((f3ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

WOODC = monthly_to_annual(fates.FATES_WOODC_SZ)

WOODC = np.squeeze(WOODC.isel(time = slice(tave_start,tave_stop)).mean(dim='time')) * agb_frac
print(WOODC.shape)
fates_agb_sd = WOODC[:,1:]/fates_sizebin_widths

for  i in range(0,len(coex)):
    f3ax0.plot(fates_sizebin_mids, fates_agb_sd[coex[i],:], 
               label = i,linewidth=2)    
    
f3ax0.set_title(r'Aboveground woody carbon by size', fontsize = 12)
f3ax0.set_ylabel(r'Kg C (m$^{-2}$ cm$^{-2}$)', fontsize = 12)
f3ax0.set_xlabel(r'DBH (cm)', fontsize = 12)    
   
plot_cwood_sz = dfss['AGB_size_kgCm.2']
    
f3ax0.plot(plot_sizebin_mids, plot_cwood_sz[1:]/plot_sizebin_widths, color='black',
           label = 'Plot Data', linewidth=3)

f3ax0.legend(prop={'size':12})
;
# Out:
# (256, 16)
# ''

# %%
time_plot = list(dfeq.Year)
agb_plot = dfeq.AGB_kgCm2
agb_plot_lower = dfeq.AGB_lower_kgCm2
agb_plot_upper = dfeq.AGB_upper_kgCm2

eq_time = np.arange(time_plot[0], (time_plot[-1]+1), 1)
tstart = nyears-(len(eq_time))
tstop = nyears

AGB = monthly_to_annual(fates.FATES_VEGC_ABOVEGROUND)

fig1, ((f1ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

for  i in range(0,len(coex)):
     f1ax0.plot(eq_time, AGB[coex[i],tstart:tstop],  label = i, linewidth=2)    
   
f1ax0.set_title(r' Equilibrium AGB', fontsize = 12)
f1ax0.set_ylabel(r'AGB (kg C m$^{-2}$)', fontsize = 12)
f1ax0.set_xlabel(r'Time (years)', fontsize = 12)    
   
f1ax0.plot(time_plot, agb_plot, color='black', label = 'Plot Data', linewidth=3)
f1ax0.fill_between(time_plot, agb_plot_lower, agb_plot_upper, alpha=0.3, facecolor='grey')

f1ax0.legend(prop={'size':10})
;
# Out:
# ''

# %% [markdown]
# ##  Load the best ensemble member

# %% [markdown]
# ### first look at coexistence

# %%
rec = 0

vegc = fates.FATES_VEGC_PF
vegc = vegc.isel(record=coex[rec])

# %%
fig2, ((f2ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

f2ax0.plot(time, vegc.isel(fates_levpft=0),label = 'ST NL')  
f2ax0.plot(time, vegc.isel(fates_levpft=1), label = 'LD BL Dec')   
f2ax0.plot(time, vegc.isel(fates_levpft=2),  label = 'ST BL Dec')   
f2ax0.plot(time, vegc.isel(fates_levpft=3),  label = 'Grass')

f2ax0.set_title(r'Veg Carbon by PFT', fontsize = 12)
f2ax0.set_ylabel(r'Biomass (kg C m$^{-2}$)', fontsize = 12)
f2ax0.set_xlabel(r'Time (years)', fontsize = 12)    
   

f2ax0.legend(prop={'size':12})

# %%
nplant = monthly_to_annual(fates.FATES_NPLANT_SZ.isel(record=coex[rec]))
print(nplant.shape)

nplant = np.squeeze(nplant.isel(time=slice(tave_start,tave_stop)).mean(dim='time')) * 10000 # convert to plants per ha (from m-2)
print(nplant.shape)

fig2, ((f2ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

f2ax0.plot(fates_sizebin_mids, nplant[1:]/fates_sizebin_widths, 
                   label = 'FATES', linewidth=2)    
   
f2ax0.set_title(r'Size distribution', fontsize = 12)
f2ax0.set_ylabel(r'Number of plants (ha$^{-1}$ cm$^{-2}$)', fontsize = 12)
f2ax0.set_xlabel(r'DBH (cm)', fontsize = 12)    
       
f2ax0.plot(plot_sizebin_mids, plot_nplant.iloc[1:]/plot_sizebin_widths, color='black',
           label = 'Plot Data', linewidth=3)
f2ax0.set_yscale('log')

f2ax0.legend(prop={'size':10})
;
# Out:
# (280, 16, 1)
# (16,)
# ''

# %%
agb_frac = 0.6

woodc = monthly_to_annual(fates.FATES_WOODC_SZ.isel(record=coex[rec]))

WOODC = np.squeeze(woodc.isel(time=slice(tave_start, tave_stop)).mean(dim='time')) * agb_frac

fates_agb_sd = WOODC[1:]/fates_sizebin_widths


fig3, ((f3ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

f3ax0.plot(fates_sizebin_mids, fates_agb_sd, 
                   label = 'FATES')    
   
f3ax0.set_title(r'Aboveground woody carbon by size', fontsize = 12)
f3ax0.set_ylabel(r'Kg C (m$^{-2}$ cm$^{-2}$)', fontsize = 12)
f3ax0.set_xlabel(r'DBH (cm)', fontsize = 12)    
      
plot_cwood_sz = dfss['AGB_size_kgCm.2']
plot_agb_sd = plot_cwood_sz[1:]/plot_sizebin_widths
    
f3ax0.plot(plot_sizebin_mids, plot_agb_sd, color='black', label = 'Plot Data', 
          linewidth=3)

f3ax0.legend(prop={'size':12})
;
# Out:
# ''

# %%
AGB = monthly_to_annual(fates.FATES_VEGC_ABOVEGROUND.isel(record=coex[rec]))

eq_time = np.arange(time_plot[0], (time_plot[-1]+1), 1)
tstart = nyears-(len(eq_time))
tstop = nyears

fig1, ((f1ax0)) = plt.subplots(nrows=1,ncols=1, figsize=(12,6))

f1ax0.plot(eq_time, AGB[tstart:tstop], label = 'FATES', linewidth=2)    
   
f1ax0.set_title(r' Equilibrium AGB', fontsize = 14)
f1ax0.set_ylabel(r'AGB (kg C m$^{-2}$)', fontsize = 14)
f1ax0.set_xlabel(r'Time (years)', fontsize = 14)    
   
f1ax0.plot(time_plot, agb_plot, color='black', label = 'Plot Data', linewidth=3)
f1ax0.fill_between(time_plot, agb_plot_lower, agb_plot_upper, alpha=0.3, facecolor='grey')

f1ax0.legend(prop={'size':14})
;
# Out:
# ''

# %%
print(coex[rec])
# Out:
# 44

# %% [markdown]
# ### Growth and mortality rates by PFT

# %%
MORTALITY_CANOPY = fates.FATES_MORTALITY_CANOPY_SZPF.isel(record=coex[rec])
MORTALITY_USTORY = fates.FATES_MORTALITY_USTORY_SZPF.isel(record=coex[rec])

NPLANT_CANOPY = fates.FATES_NPLANT_CANOPY_SZPF.isel(record=coex[rec])
NPLANT_USTORY = fates.FATES_NPLANT_USTORY_SZPF.isel(record=coex[rec])

# untangle them all
MORTALITY_CANOPY = np.squeeze(fa.scpf_to_scls_by_pft(MORTALITY_CANOPY, fates))
MORTALITY_USTORY = np.squeeze(fa.scpf_to_scls_by_pft(MORTALITY_USTORY, fates))
NPLANT_CANOPY = np.squeeze(fa.scpf_to_scls_by_pft(NPLANT_CANOPY, fates))
NPLANT_USTORY = np.squeeze(fa.scpf_to_scls_by_pft(NPLANT_USTORY, fates))

# %%
print(NPLANT_CANOPY.shape)
# Out:
# (3360, 4, 16)

# %%
# set up the page
fig3, ((f3ax0, f3ax1, f3ax2), (f3ax3, f3ax4, f3ax5)) = plt.subplots(nrows=2, ncols=3, figsize=(12, 7))

levels = np.arange(0.,0.1, 0.005)
cmap = plt.get_cmap('Reds')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)


im = f3ax0.pcolormesh(time, cohort_size_bins, 
                      (MORTALITY_CANOPY.isel(fates_levpft=0) / NPLANT_CANOPY.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax0)
f3ax0.set_title(r'Mortality rate of canopy plants PFT 1 (DBH yr$^{-1}$)')
f3ax0.set_xlabel('Time (yr)')
f3ax0.set_ylabel('Cohort Size (cm)')

im = f3ax1.pcolormesh(time, cohort_size_bins, 
                      (MORTALITY_CANOPY.isel(fates_levpft=1) / NPLANT_CANOPY.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax1)
f3ax1.set_title(r'Mortality rate of canopy plants PFT 2 (DBH yr$^{-1}$)')
f3ax1.set_xlabel('Time (yr)')
f3ax1.set_ylabel('Cohort Size (cm)')

im = f3ax2.pcolormesh(time, cohort_size_bins, 
                      (MORTALITY_CANOPY.isel(fates_levpft=2) / NPLANT_CANOPY.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax2)
f3ax2.set_title(r'Mortality rate of canopy plants PFT 3 (DBH yr$^{-1}$)')
f3ax2.set_xlabel('Time (yr)')
f3ax2.set_ylabel('Cohort Size (cm)')


levels = np.arange(0.,1.0, 0.05)
cmap = plt.get_cmap('Reds')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)


im = f3ax3.pcolormesh(time, cohort_size_bins, 
                      (MORTALITY_USTORY.isel(fates_levpft=0) / NPLANT_USTORY.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax3)
f3ax3.set_title(r'Mortality rate of understory plants (DBH yr$^{-1}$)')
f3ax3.set_xlabel('Time (yr)')
f3ax3.set_ylabel('Cohort Size (cm)')

im = f3ax4.pcolormesh(time, cohort_size_bins, 
                      (MORTALITY_USTORY.isel(fates_levpft=1) / NPLANT_USTORY.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax4)
f3ax4.set_title(r'Mortality rate of understory plants (DBH yr$^{-1}$)')
f3ax4.set_xlabel('Time (yr)')
f3ax4.set_ylabel('Cohort Size (cm)')

im = f3ax5.pcolormesh(time, cohort_size_bins, 
                      (MORTALITY_USTORY.isel(fates_levpft=2) / NPLANT_USTORY.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax5)
f3ax5.set_title(r'Mortality rate of understory plants (DBH yr$^{-1}$)')
f3ax5.set_xlabel('Time (yr)')
f3ax5.set_ylabel('Cohort Size (cm)')

fig3.tight_layout()

# %%
# set up the page
fig3, ((f3ax0, f3ax1, f3ax2), (f3ax3, f3ax4, f3ax5)) = plt.subplots(nrows=2, ncols=3, figsize=(12, 7))

levels = np.array([0.1,0.3,1.,3.,10.,30., 100.,300.,1000., 3000., 10000.]) # do a pseudo-log scale here
cmap = plt.get_cmap('Greens')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

im = f3ax0.pcolormesh(time, cohort_size_bins, 
                      NPLANT_CANOPY.isel(fates_levpft=0).transpose() *10000, 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax0)
f3ax0.set_title(r'No. plants canopy PFT 1 (ha$^{-1}$)')
f3ax0.set_xlabel('Time (yr)')
f3ax0.set_ylabel('Cohort Size (cm)')

im = f3ax1.pcolormesh(time, cohort_size_bins, 
                      NPLANT_CANOPY.isel(fates_levpft=1).transpose() *10000, 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax1)
f3ax1.set_title(r'No. plants canopy PFT 2 (ha$^{-1}$)')
f3ax1.set_xlabel('Time (yr)')
f3ax1.set_ylabel('Cohort Size (cm)')

im = f3ax2.pcolormesh(time, cohort_size_bins, 
                      NPLANT_CANOPY.isel(fates_levpft=2).transpose()*10000, 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax2)
f3ax2.set_title(r'No. plants canopy PFT 3 (har$^{-1}$)')
f3ax2.set_xlabel('Time (yr)')
f3ax2.set_ylabel('Cohort Size (cm)')

im = f3ax3.pcolormesh(time, cohort_size_bins, 
                      NPLANT_USTORY.isel(fates_levpft=0).transpose()*10000, 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax3)
f3ax3.set_title(r'No. plants understory PFT 1 (ha$^{-1}$)')
f3ax3.set_xlabel('Time (yr)')
f3ax3.set_ylabel('Cohort Size (cm)')

im = f3ax4.pcolormesh(time, cohort_size_bins, 
                      NPLANT_USTORY.isel(fates_levpft=1).transpose()*10000, 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax4)
f3ax4.set_title(r'No. plants understory PFT 2 (ha$^{-1}$)')
f3ax4.set_xlabel('Time (yr)')
f3ax4.set_ylabel('Cohort Size (cm)')

im = f3ax5.pcolormesh(time, cohort_size_bins, 
                      NPLANT_USTORY.isel(fates_levpft=2).transpose()*10000, 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax5)
f3ax5.set_title(r'No. plants understory PFT 3 (ha$^{-1}$)')
f3ax5.set_xlabel('Time (yr)')
f3ax5.set_ylabel('Cohort Size (cm)')

fig3.tight_layout()

# %% [markdown]
# ### What is the needle leaf PFT dying of?

# %%
nplant = fates.FATES_NPLANT_SZPF.isel(record=coex[rec])
nplant = np.squeeze(fa.scpf_to_scls_by_pft(nplant, fates))

cstarv = fates.FATES_MORTALITY_CSTARV_SZPF.isel(record=coex[rec])
cstarv = np.squeeze(fa.scpf_to_scls_by_pft(cstarv, fates))

hydro = fates.FATES_MORTALITY_HYDRAULIC_SZPF.isel(record=coex[rec])
hydro = np.squeeze(fa.scpf_to_scls_by_pft(hydro, fates))

term = fates.FATES_MORTALITY_TERMINATION_SZPF.isel(record=coex[rec])
term = np.squeeze(fa.scpf_to_scls_by_pft(term, fates))

freeze = fates.FATES_MORTALITY_FREEZING_SZPF.isel(record=coex[rec])
freeze = np.squeeze(fa.scpf_to_scls_by_pft(freeze, fates))

impact = fates.FATES_MORTALITY_IMPACT_SZPF.isel(record=coex[rec])
impact = np.squeeze(fa.scpf_to_scls_by_pft(impact, fates))

bg = fates.FATES_MORTALITY_BACKGROUND_SZPF.isel(record=coex[rec])
bg = np.squeeze(fa.scpf_to_scls_by_pft(bg, fates))

print(cstarv.shape)
# Out:
# (3360, 4, 16)

# %%
# set up the page
fig3, ((f3ax0, f3ax1, f3ax2), (f3ax3, f3ax4, f3ax5), (f3ax6, f3ax7, f3ax8)) = plt.subplots(nrows=3, ncols=3, figsize=(12, 10))

levels = np.arange(0.,0.1, 0.005)
cmap = plt.get_cmap('Reds')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)


im = f3ax0.pcolormesh(time, cohort_size_bins, 
                      (cstarv.isel(fates_levpft=0) / nplant.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax0)
f3ax0.set_title(r'c starv PFT 1')
f3ax0.set_xlabel('Time (yr)')
f3ax0.set_ylabel('Cohort Size (cm)')

im = f3ax1.pcolormesh(time, cohort_size_bins, 
                      (cstarv.isel(fates_levpft=1) / nplant.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax1)
f3ax1.set_title(r'c starv PFT 2')
f3ax1.set_xlabel('Time (yr)')
f3ax1.set_ylabel('Cohort Size (cm)')

im = f3ax2.pcolormesh(time, cohort_size_bins, 
                      (cstarv.isel(fates_levpft=2) / nplant.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax2)
f3ax2.set_title(r'cstarv PFT 3')
f3ax2.set_xlabel('Time (yr)')
f3ax2.set_ylabel('Cohort Size (cm)')


im = f3ax3.pcolormesh(time, cohort_size_bins, 
                      (hydro.isel(fates_levpft=0) / nplant.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax3)
f3ax3.set_title(r'Hydro PFT 1')
f3ax3.set_xlabel('Time (yr)')
f3ax3.set_ylabel('Cohort Size (cm)')

im = f3ax4.pcolormesh(time, cohort_size_bins, 
                      (hydro.isel(fates_levpft=1) / nplant.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax4)
f3ax4.set_title(r'Hydro PFT 2')
f3ax4.set_xlabel('Time (yr)')
f3ax4.set_ylabel('Cohort Size (cm)')

im = f3ax5.pcolormesh(time, cohort_size_bins, 
                      (hydro.isel(fates_levpft=2) / nplant.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax5)
f3ax5.set_title(r'Hydro PFT 3')
f3ax5.set_xlabel('Time (yr)')
f3ax5.set_ylabel('Cohort Size (cm)')



im = f3ax6.pcolormesh(time, cohort_size_bins, 
                      (bg.isel(fates_levpft=0) / nplant.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax6)
f3ax6.set_title(r'Background PFT 1')
f3ax6.set_xlabel('Time (yr)')
f3ax6.set_ylabel('Cohort Size (cm)')

im = f3ax7.pcolormesh(time, cohort_size_bins, 
                      (bg.isel(fates_levpft=1) / nplant.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax7)
f3ax7.set_title(r'Background PFT 2')
f3ax7.set_xlabel('Time (yr)')
f3ax7.set_ylabel('Cohort Size (cm)')

im = f3ax8.pcolormesh(time, cohort_size_bins, 
                      (bg.isel(fates_levpft=2) / nplant.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax8)
f3ax8.set_title(r'Background PFT 3')
f3ax8.set_xlabel('Time (yr)')
f3ax8.set_ylabel('Cohort Size (cm)')

fig3.tight_layout()

# %%
# set up the page
fig3, ((f3ax0, f3ax1, f3ax2), (f3ax3, f3ax4, f3ax5), (f3ax6, f3ax7, f3ax8)) = plt.subplots(nrows=3, ncols=3, figsize=(12, 10))

levels = np.arange(0.,0.1, 0.005)
cmap = plt.get_cmap('Reds')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)


im = f3ax0.pcolormesh(time, cohort_size_bins, 
                      (term.isel(fates_levpft=0) / nplant.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax0)
f3ax0.set_title(r'Termination PFT 1')
f3ax0.set_xlabel('Time (yr)')
f3ax0.set_ylabel('Cohort Size (cm)')

im = f3ax1.pcolormesh(time, cohort_size_bins, 
                      (term.isel(fates_levpft=1) / nplant.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax1)
f3ax1.set_title(r'Termination PFT 2')
f3ax1.set_xlabel('Time (yr)')
f3ax1.set_ylabel('Cohort Size (cm)')

im = f3ax2.pcolormesh(time, cohort_size_bins, 
                      (term.isel(fates_levpft=2) / nplant.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax2)
f3ax2.set_title(r'Termination PFT 3')
f3ax2.set_xlabel('Time (yr)')
f3ax2.set_ylabel('Cohort Size (cm)')


im = f3ax3.pcolormesh(time, cohort_size_bins, 
                      (freeze.isel(fates_levpft=0) / nplant.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax3)
f3ax3.set_title(r'Freeze PFT 1')
f3ax3.set_xlabel('Time (yr)')
f3ax3.set_ylabel('Cohort Size (cm)')

im = f3ax4.pcolormesh(time, cohort_size_bins, 
                      (freeze.isel(fates_levpft=1) / nplant.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax4)
f3ax4.set_title(r'Freeze PFT 2')
f3ax4.set_xlabel('Time (yr)')
f3ax4.set_ylabel('Cohort Size (cm)')

im = f3ax5.pcolormesh(time, cohort_size_bins, 
                      (freeze.isel(fates_levpft=2) / nplant.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax5)
f3ax5.set_title(r'Freeze PFT 3')
f3ax5.set_xlabel('Time (yr)')
f3ax5.set_ylabel('Cohort Size (cm)')

im = f3ax6.pcolormesh(time, cohort_size_bins, 
                      (impact.isel(fates_levpft=0) / nplant.isel(fates_levpft=0)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax6)
f3ax6.set_title(r'Impact PFT 1')
f3ax6.set_xlabel('Time (yr)')
f3ax6.set_ylabel('Cohort Size (cm)')

im = f3ax7.pcolormesh(time, cohort_size_bins, 
                      (impact.isel(fates_levpft=1) / nplant.isel(fates_levpft=1)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax7)
f3ax7.set_title(r'Impact PFT 2')
f3ax7.set_xlabel('Time (yr)')
f3ax7.set_ylabel('Cohort Size (cm)')

im = f3ax8.pcolormesh(time, cohort_size_bins, 
                      (impact.isel(fates_levpft=2) / nplant.isel(fates_levpft=2)).transpose(), 
                      cmap=cmap, norm=norm)
fig3.colorbar(im, ax=f3ax8)
f3ax8.set_title(r'Impact PFT 3')
f3ax8.set_xlabel('Time (yr)')
f3ax8.set_ylabel('Cohort Size (cm)')

fig3.tight_layout()
